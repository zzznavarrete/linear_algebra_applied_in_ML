# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# %run "./aux_functions/graficarVectores.ipynb"
# %run "./aux_functions/graficarMatriz.ipynb"

# %%
A = np.array([[3, 7], [5, 2]])
print(A)
# Out:
# [[3 7]
#  [5 2]]

# %%
U, D, V = np.linalg.svd(A)

print(D[0])
print(D[1])
# Out:
# 8.7133796929634
# 3.3282148858288965

# %%
u1 = [D[0]*U[0,0], D[0]*U[0,1]]
v1 = [D[1]*U[1,0], D[1]*U[1,1]]

print([A[0,0], A[1,0]])
print(u1)
print()
print([A[0,1], A[1,1]])
print(v1)
# Out:
# [3, 5]
# [-7.412043479297569, -4.580894796297923]
#
# [7, 2]
# [-1.7497461132982814, 2.8311486829996433]

# %%
graficarMatriz(A)
graficarVectores([u1, v1], colors=['red', 'blue'])

plt.text(3, 5, r"$u_1$", size = 18)
plt.text(7, 2, r"$v_1$", size = 18)

plt.text(-5, 4, r"$D(u_1)$", size = 18)
plt.text(-4, -1, r"$D(v_1)$", size = 18)

plt.xlim(-8, 8)
plt.ylim(-8, 8)

plt.show()
